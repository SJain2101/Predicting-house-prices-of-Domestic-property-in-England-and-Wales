# %%
import random

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder

# %%
columns = [
    'Transaction_Unique_Identifier',  # *
    'Price',
    'Date_of_Transfer',
    'Post_Code',  # *
    'Property_Type',
    'Old_New',
    'Duration',
    'PAON',  # *
    'SAON',  # *
    'Street',  # *
    'Locality',  # *
    'Town_City',
    'District',
    'County',
    'PPDCategory_Type',
    'Record_Status'
]
original_df = pd.read_csv('data/pp-2021.csv', names=columns)
original_df['Date_of_Transfer'] = pd.to_datetime(original_df['Date_of_Transfer'])

# %%
print(original_df.shape)
original_df.head()
# Out:
# (554279, 16)
#             Transaction_Unique_Identifier   Price Date_of_Transfer Post_Code  \
# 0  {C8A3A576-4E89-0425-E053-6C04A8C0947B}  140000       2021-03-18   BB1 8BT
# 1  {C8A3A576-4E8A-0425-E053-6C04A8C0947B}   80500       2021-06-18   FY7 7ND
# 2  {C8A3A576-4E8B-0425-E053-6C04A8C0947B}  220000       2021-06-18  PR26 7AW
# 3  {C8A3A576-4E8C-0425-E053-6C04A8C0947B}  166000       2021-07-14   PR4 3UN
# 4  {C8A3A576-4E8E-0425-E053-6C04A8C0947B}   75000       2021-04-26  BB10 4LF
#
#   Property_Type Old_New Duration PAON SAON             Street Locality  \
# 0             T       N        F   26  NaN        PARK AVENUE      NaN
# 1             T       N        F    3  NaN  NORTHFLEET AVENUE      NaN
# 2             D       N        F   91  NaN          FERNLEIGH      NaN
# 3             S       N        F   18  NaN     PREESE GARDENS  ELSWICK
# 4             S       N        F   88  NaN    WYCOLLER AVENUE      NaN
#
#    Town_City               District                 County PPDCategory_Type  \
# 0  BLACKBURN  BLACKBURN WITH DARWEN  BLACKBURN WITH DARWEN                A
# 1  FLEETWOOD                   WYRE             LANCASHIRE                B
# 2    LEYLAND           SOUTH RIBBLE             LANCASHIRE                A
# 3    PRESTON                  FYLDE             LANCASHIRE                A
# 4    BURNLEY                BURNLEY             LANCASHIRE                A
#
#   Record_Status
# 0             A
# 1             A
# 2             A
# 3             A
# 4             A

# %%
(original_df.isna().sum() / original_df.shape[0]) * 100
# Out:
# Transaction_Unique_Identifier     0.000000
# Price                             0.000000
# Date_of_Transfer                  0.000000
# Post_Code                         0.318071
# Property_Type                     0.000000
# Old_New                           0.000000
# Duration                          0.000000
# PAON                              0.000000
# SAON                             89.949466
# Street                            2.046262
# Locality                         61.628169
# Town_City                         0.000000
# District                          0.000000
# County                            0.000000
# PPDCategory_Type                  0.000000
# Record_Status                     0.000000
# dtype: float64

# %%
dropped_columns = [
    'Transaction_Unique_Identifier',
    'SAON',
    'PAON',
    'Street',
    'Locality',
    'Date_of_Transfer',
    'Record_Status',
]

base_df = original_df.drop(dropped_columns, axis=1)
base_df
# Out:
#          Price Post_Code Property_Type Old_New Duration    Town_City  \
# 0       140000   BB1 8BT             T       N        F    BLACKBURN
# 1        80500   FY7 7ND             T       N        F    FLEETWOOD
# 2       220000  PR26 7AW             D       N        F      LEYLAND
# 3       166000   PR4 3UN             S       N        F      PRESTON
# 4        75000  BB10 4LF             S       N        F      BURNLEY
# ...        ...       ...           ...     ...      ...          ...
# 554274  299995  CF64 5WE             D       Y        F      PENARTH
# 554275  250000  LL17 0PY             D       N        F     ST ASAPH
# 554276  278995  NP12 2QU             D       Y        F    BLACKWOOD
# 554277  310000  CF64 5WD             D       Y        F      PENARTH
# 554278  335950   NP7 5DX             F       Y        L  ABERGAVENNY
#
#                      District                 County PPDCategory_Type
# 0       BLACKBURN WITH DARWEN  BLACKBURN WITH DARWEN                A
# 1                        WYRE             LANCASHIRE                B
# 2                SOUTH RIBBLE             LANCASHIRE                A
# 3                       FYLDE             LANCASHIRE                A
# 4                     BURNLEY             LANCASHIRE                A
# ...                       ...                    ...              ...
# 554274  THE VALE OF GLAMORGAN  THE VALE OF GLAMORGAN                A
# 554275           DENBIGHSHIRE           DENBIGHSHIRE                A
# 554276             CAERPHILLY             CAERPHILLY                A
# 554277  THE VALE OF GLAMORGAN  THE VALE OF GLAMORGAN                A
# 554278          MONMOUTHSHIRE          MONMOUTHSHIRE                A
#
# [554279 rows x 9 columns]

# %% [markdown]
# ## Select Resolution

# %%
geo_dropped_columns = [
    'Post_Code',
    'Town_City',
    'District',
    'County',
]

geo_res_df = base_df.drop(geo_dropped_columns, axis=1)
geo_res_df
# Out:
#          Price Property_Type Old_New Duration PPDCategory_Type
# 0       140000             T       N        F                A
# 1        80500             T       N        F                B
# 2       220000             D       N        F                A
# 3       166000             S       N        F                A
# 4        75000             S       N        F                A
# ...        ...           ...     ...      ...              ...
# 554274  299995             D       Y        F                A
# 554275  250000             D       N        F                A
# 554276  278995             D       Y        F                A
# 554277  310000             D       Y        F                A
# 554278  335950             F       Y        L                A
#
# [554279 rows x 5 columns]

# %% [markdown]
# ## One Hot Encoding

# %%
encoded_columns = [
    'Property_Type',
    'Old_New',
    'Duration',
    'PPDCategory_Type',
]

enc_df = geo_res_df.copy()
for enc_col in encoded_columns:
    enc_df = pd.concat([
            enc_df, 
            pd.get_dummies(
                enc_df[enc_col], prefix=enc_col,
                drop_first=True, sparse=False
            )
        ],
        axis=1
    )
    enc_df = enc_df.drop(enc_col, axis=1)
enc_df
# Out:
#          Price  Property_Type_F  Property_Type_O  Property_Type_S  \
# 0       140000                0                0                0
# 1        80500                0                0                0
# 2       220000                0                0                0
# 3       166000                0                0                1
# 4        75000                0                0                1
# ...        ...              ...              ...              ...
# 554274  299995                0                0                0
# 554275  250000                0                0                0
# 554276  278995                0                0                0
# 554277  310000                0                0                0
# 554278  335950                1                0                0
#
#         Property_Type_T  Old_New_Y  Duration_L  PPDCategory_Type_B
# 0                     1          0           0                   0
# 1                     1          0           0                   1
# 2                     0          0           0                   0
# 3                     0          0           0                   0
# 4                     0          0           0                   0
# ...                 ...        ...         ...                 ...
# 554274                0          1           0                   0
# 554275                0          0           0                   0
# 554276                0          1           0                   0
# 554277                0          1           0                   0
# 554278                0          1           1                   0
#
# [554279 rows x 8 columns]

# %%
enc_df.to_csv('data/ppd2.csv', index=False)
